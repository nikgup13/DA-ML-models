# %% [markdown]
# ## USA - Regression + Null Hypothesis on 2014-2015 data - SUMMARY
#
# > The libraries that we needed – MASS, ISLR, xlsx, car, cluster - are installed and called.
#
# > We read the csv file for 2014, 2015 and 2016.
#
# > We removed the NA values from both the files.
#
# > The respective data is converted into data-frame.
# >  Then a new column named aggravated_assault_2016 is added in data for 2014 for the prediction of mean of violent crime per 10.000 of population for 2016.
#
# > Then another column named m2014 is added in data for 2014 in which mean value of violent crime of 2014 is calculate per 10,000 of population.
#
# > Then multiple variable linear regression is done for m2014 where m2014 is dependent variable and all types of violent crime are independent variables.
#
# >  We noticed that p value for ‘Murder and slaughter’ is very high as compared to other variables which means it does not fit the data to a large extent so we removed it from the fit and again did linear regression ‘lm.fit14’.
#
# > We find the confidence interval for estimate of coefficients.
#
# > Then we predicted the value of m2014 for all values of aggravated assault of 2014.
#
# > Then we predicted the value of m2014 for those value of aggravated assault which are in 2016 which gives the approximated mean violent crime per 10,000 of population for 2016.
#
# ####  We observed the trends in 2014 and 2015 and concluded that:
#
# *  m2014 and m2015 are almost same as analyzed by null-hypothesis so m2016 will also be approximately same.
# *  By multiple linear regression, we found that the trends in p-value for both 2014 and 2015 are almost same so same can be predicted for 2016 and in both the years, aggravated assault value has the least p-value so we used the value of aggravated assault of 2016 and predicted m2016 by predicting m2014 for aggravated assault of 2016.
# *  We even observed that they are approximately same as m2014.
#
# > We plotted m2014 vs aggravated assault of 2014. We also did abline plot and we observed that plot is done for 3 variables as we can see that most data is concentrated in starting only so rest points can be considered as outliers.
#
# > We plotted hatvalues for lm.fit14 which gives leverage statistics.
#
# > Then index of maximum variable is found.
#
# > Same is done for 2015 but prediction for m2016 is done only by 2014 data.
#
# > This is followed by performing null hypothesis which was that m2014 and m2015 are equal because if they are equal, then our base of predictions for 2016 is correct. We found that our null hypothesis is accepted and hence out predictions.

# %%
#calling required libraries

library(xlsx)
library(rJava)
library(xlsxjars)

library (rJava)
library (xlsxjars)
library (MASS)
library (ISLR)
library (car)
library (cluster)

# %%
#reading csv file for usa crime 2014,2015 and 2016

data = read.csv('USA_regression_14.csv')
data1 = read.csv('USA_regression_15.csv')
data16 = read.csv('USA_regression_16.csv', sep = ',')

#converting to dataframe

data14=data.frame(data)
data15=data.frame(data1)
data16_df = data.frame(data16)

x = data16_df$'Aggravated.assault' #putting value of aggravate assault for 2016 in x
y = x[0:146] #extracting 146 rows

# %%
#2014

fix(data14)
names(data14)
data14["aggravated_assault_2016"]<- y #making column for aggarvated assault of 2016
data14["m2014"]<- data14["Violent.crime"]*10000/ data14["Population"] #making column for mean population per 10,000 people statewise
data14

# multiple variable linear regression with m2014 as dependent variable and other types of violent crimes as independent variables

lm.fit=lm(m2014~ Murder.and.nonnegligent.manslaughter + Rape..revised.definition. + Robbery + Rape..legacy.definition. + Aggravated.assault, data=data14)
summary(lm.fit)
# Out:
#  [1] "X"
#  [2] "State"
#  [3] "Area"
#  [4] "Population"
#  [5] "Violent.crime"
#  [6] "Murder.and.nonnegligent.manslaughter"
# 136 191 WASHINGTON           Cities outside metropolitan areas   294301
# 137 192 WASHINGTON           Nonmetropolitan counties            419649
# 138 194 WEST VIRGINIA        Metropolitan Statistical Area      1138730
# 139 195 WEST VIRGINIA        Cities outside metropolitan areas   190438
# 140 196 WEST VIRGINIA        Nonmetropolitan counties            521158
# 141 198 WISCONSIN            Metropolitan Statistical Area      4251567
# 142 199 WISCONSIN            Cities outside metropolitan areas   637105
# 143 200 WISCONSIN            Nonmetropolitan counties            868892
# 144 202 WYOMING              Metropolitan Statistical Area       178196
# 145 203 WYOMING              Cities outside metropolitan areas   246602
# 146 204 WYOMING              Nonmetropolitan counties            159355
#     Violent.crime Murder.and.nonnegligent.manslaughter
# 1    16204         232
# 2     2605          17
# 3     1247          22
# 4     2899          17
# 5      722           3
# 6     1037          21
# 7    24006         288
# 8     1721          20
# 9      433           1
# 10    9939         109
# 11    2349          27
# 12    1340          23
# 13  150171        1652
# 14    1524          16
# 15    1993          31
# 16   15229         126
# 17     735          15
# 18     398           8
# 19    8068          82
# 20     108           2
# 21     346           2
# 22    4575          54
# 23    8199         105
# 24  104161        1133
# 25     921           4
# 26    2159          11
# 27   32097         508
# 28    3041          30
# 29    2179          36
# 30    2901          15
# ... ...           ...
# 117   1374           9
# 118   1168           6
# 119    144           4
# 120  33938         319
# 121   3203          21
# 122   2599          30
# 123 100224        1079
# 124   5676          50
# 125   3117          52
# 126   5739          54
# 127    287           1
# 128    290          12
# 129    214           2
# 130    260           1
# 131    148           7
# 132  14412         284
# 133    694          15
# 134   1225          39
# 135  18604         159
# 136    944           7
# 137    559           8
# 138   3310          44
# 139    425           6
# 140   1197          16
# 141  14725         142
# 142   1019          11
# 143    752          10
# 144    305           6
# 145    580           6
# 146    222           4
#     Rape..revised.definition. Robbery Rape..legacy.definition.
# 1    1435                      4131   1033
# 2     294                       363    214
# 3     199                        86    133
# 4     442                       557    329
# 5     128                        45     93
# 6     196                        25    128
# 7    2762                      6117   2024
# 8     452                        55    323
# 9      13                        24     10
# 10    958                      1671    699
# 11    383                       284    227
# 12    296                        42    170
# 13  11088                     48278   8096
# 14    168                       257    126
# 15    270                       138    175
# 16   2700                      2952   1943
# 17    191                        60     96
# 18    104                        12     51
# 19    686                      3106    513
# 20     11                        22      8
# 21     85                        31     50
# 22    385                      1269    249
# 23    472                      3497    352
# 24   8298                     24552   5872
# 25     53                       163     38
# 26    184                       154    121
# 27   2487                     11368   1769
# 28    255                       704    188
# 29    215                       175    134
# 30    310                       994    225
# ... ...                       ...     ...
# 117   259                       150    238
# 118   163                        43    139
# 119    27                         4     22
# 120  2154                      6823   1575
# 121   183                       312    144
# 122   184                       116    135
# 123 10227                     30369   7407
# 124   603                       609    438
# 125   502                       145    342
# 126  1290                      1287    839
# 127   100                        13     63
# 128    55                         9     36
# 129    22                        24     20
# 130    47                        38     41
# 131    41                         8     38
# 132  1880                      4039   1206
# 133   113                       144     65
# 134   317                       107    161
# 135  2438                      5439   1954
# 136   170                       148    144
# 137    83                        47     69
# 138   333                       530    175
# 139    29                        29     22
# 140    99                        37     54
# 141  1232                      4918    851
# 142   214                        73    163
# 143   189                        28    124
# 144    37                        30     25
# 145    80                        18     61
# 146    50                         5     35
#     Aggravated.assault aggravated_assault_2016 m2014
# 1   10406              480                      43.888302
# 2    1931              573                      49.231851
# 3     940              1,005                    19.852009
# 4    1883              1,055                    82.496699
# 5     546              129                      56.107739
# 6     795              141                      40.406323
# 7   14839              65                       37.609463
# 8    1194              71                      139.220334
# 9     395              652                      19.253087
# 10   7201              701                      54.658542
# 11   1655              103                      46.259463
# 12    979              110                      20.930926
# 13  89153              85                       39.549265
# 14   1083              81                       56.781770
# 15   1554              216                      35.369050
# 16   9451              253                      32.652160
# 17    469              961                      21.992095
# 18    274              1,219                    11.128354
# 19   4194              911                      27.365869
# 20     73              1,018                     9.312914
# 21    228              342                       6.497518
# 22   2867              363                      48.898370
# 23   4125              219                     124.435986
# 24  70178              199                      54.290093
# 25    701              505                      62.110963
# 26   1810              580                      38.621918
# 27  17734              84                       38.576511
# 28   2052              84                       45.887411
# 29   1753              39                       19.555123
# 30   1582              70                       25.089448
# ... ...                ...                     ...
# 117   956              735                     33.868558
# 118   956              869                     53.467368
# 119   109              1,916                    6.287166
# 120 24642              1,600                   67.156924
# 121  2687              1,358                   62.049954
# 122  2269              1,302                   26.530750
# 123 58549              930                     41.922334
# 124  4414              1,091                   39.934119
# 125  2418              86                      19.139714
# 126  3108              75                      21.843086
# 127   173              439                     20.445382
# 128   214              511                     16.557048
# 129   166              33                       9.929196
# 130   174              43                      12.550564
# 131    92              86                       7.259386
# 132  8209              78                      19.833346
# 133   422              117                     26.246918
# 134   762              146                     15.402470
# 135 10568              205                     29.308807
# 136   619              223                     32.076004
# 137   421              50                      13.320656
# 138  2403              49                      29.067470
# 139   361              1,366                   22.316975
# 140  1045              1,498                   22.968083
# 141  8433              27                      34.634289
# 142   721              39                      15.994224
# 143   525              26                       8.654700
# 144   232              30                      17.115985
# 145   476              35                      23.519679
# 146   163              50                      13.931160
# Call:
# lm(formula = m2014 ~ Murder.and.nonnegligent.manslaughter + Rape..revised.definition. +
#     Robbery + Rape..legacy.definition. + Aggravated.assault,
#     data = data14)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -23.064 -12.727  -4.907   6.796 109.456
#
# Coefficients:
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                          29.0731742  1.9512630  14.900   <2e-16 ***
# Murder.and.nonnegligent.manslaughter  0.0159043  0.0281727   0.565   0.5733
# Rape..revised.definition.            -0.0366298  0.0254953  -1.437   0.1530
# Robbery                              -0.0026755  0.0015207  -1.759   0.0807 .
# Rape..legacy.definition.              0.0460830  0.0345457   1.334   0.1844
# Aggravated.assault                    0.0018362  0.0007493   2.450   0.0155 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 20.17 on 140 degrees of freedom
# Multiple R-squared:  0.08041,	Adjusted R-squared:  0.04757
# F-statistic: 2.448 on 5 and 140 DF,  p-value: 0.03676

# %%
#we remove murder column as it has high p-value and we can see that aggravated assault has very low p-value so it fits the data very well

lm.fit14=lm(m2014~ Rape..revised.definition. + Robbery + Rape..legacy.definition. + Aggravated.assault, data=data14)
summary(lm.fit14)

#calculating confidence interval
confint(lm.fit14) 

attach(data14)
predict(lm.fit14, data.frame(Aggravated.assault,interval ="confidence")) #predicting the value of m2014 for all the values of aggravated values

attach(data14)
predict(lm.fit14, data.frame(Aggravated.assault=c(480,573,1005,1055,129,141,65,71,652,701,103,110,85,81,216,253,961,1219,911,1018,342,363,219,199,505,580,84,84,39,70,55,46,165,232,73,76,135,131,42,25,94,100,75,73,53,90,91,105,225,201,115,117,146,162,148,166,263,289,54,74,762,962,162,154,47,51,93,87,105,114,168,161,24,25,287,334,740,741,6308,7531,689,745,139,280,15,31,111,117,1264,1287,172,203,147,175,57,64,235,217,257,226,109,141,212,164,47,62,114,159,209,255,360,470,1183,1142,313,254,735,869,1916,1600,1358,1302,930,1091,86,75,439,511,33,43,86,78,117,146,205,223,50,49,1366,1498,27,39,26,30,35,523), interval ="confidence")) #predicting m2014(which is approximately equal to m2016 when predicted with values of aggravated assault of 2016) using the aggravated assault values of 2016
# Out:
# Call:
# lm(formula = m2014 ~ Rape..revised.definition. + Robbery + Rape..legacy.definition. +
#     Aggravated.assault, data = data14)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -23.221 -12.889  -5.109   6.886 109.383
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)               29.2948466  1.9067213  15.364   <2e-16 ***
# Rape..revised.definition. -0.0330485  0.0246337  -1.342   0.1819
# Robbery                   -0.0022036  0.0012672  -1.739   0.0842 .
# Rape..legacy.definition.   0.0413974  0.0334527   1.237   0.2180
# Aggravated.assault         0.0018678  0.0007454   2.506   0.0134 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 20.12 on 141 degrees of freedom
# Multiple R-squared:  0.07832,	Adjusted R-squared:  0.05217
# F-statistic: 2.995 on 4 and 141 DF,  p-value: 0.02077
#                           2.5 %         97.5 %
# (Intercept)               25.5253891447 33.064303997
# Rape..revised.definition. -0.0817476447  0.015650663
# Robbery                   -0.0047087716  0.000301616
# Rape..legacy.definition.  -0.0247362103  0.107531049
# Aggravated.assault         0.0003941399  0.003341504
# The following objects are masked from data15 (pos = 3):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 4):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 5):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 6):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 7):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 8):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 9):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 10):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data15 (pos = 11):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 12):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 13):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 14):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#        1        2        3        4        5        6        7        8
# 34.96737 31.24450 29.79030 30.59688 29.83527 29.54604 36.04062 29.83728
#        9       10       11       12       13       14       15       16
# 29.96409 36.33920 28.49992 28.28610 58.14430 30.41531 30.21480 31.64693
#       17       18       19       20       21       22       23       24
# 27.70053 28.45441 28.84979 29.35036 28.91315 29.43784 28.26671 75.12189
#       25       26       27       28       29       30       31       32
# 30.06654 31.26442 28.40897 30.93165 30.62534 29.12877 29.23993 31.20831
#       33       34       35       36       37       38       39       40
#   30.669075  -15.501649   25.840731   23.268836   17.559733   28.458294
#          67          68          69          70          71          72
#   28.077698   25.940636   28.150419   28.570556   11.431299   28.485718
#          73          74          75          76          77          78
#   28.308298   28.738830   29.884444   30.022224   26.746289   30.021721
#          79          80          81          82          83          84
#   40.706804   27.235160   30.464645   30.171842   28.301460   29.345707
#          85          86          87          88          89          90
#   29.228355    3.567552   22.616106   28.204415   30.948047  -33.803436
#          91          92          93          94          95          96
#   28.584094   26.066897    7.955569   27.439044   26.959171   29.337556
#          97          98          99         100         101         102
#   29.266668   29.457221    8.376305   29.652672   27.995879   19.737087
#         103         104         105         106         107         108
#   27.583099   28.950848   22.333724   28.333087   29.019802   -8.542177
#         109         110         111         112         113         114
#   29.082627   27.646110   18.692379   29.899484   29.296618   17.885681
#         115         116         117         118         119         120
#   29.119124   28.380212   31.630186   31.190567   32.883213   11.262837
#         121         122         123         124         125         126
#   31.057187   30.978865  -67.244765   28.194491   26.703535   18.698810
#         127         128         129         130         131         132
#   29.389362   29.902112   29.404480   29.435442   29.655964    8.334411
#         133         134         135         136         137         138
#   28.152419   25.520379   18.010827   29.728226   29.398067   24.457875
#         139         140         141         142         143         144
#   31.734725   30.974972   13.021545   28.882233   28.168825   29.096915
#         145         146
#   29.201919   30.057185

# %%
#plotting aggravated assault vs m2014 

plot(Aggravated.assault, m2014)
abline(lm.fit14)
# Out:
# Warning message in abline(lm.fit14):
# "only using the first two of 5 regression coefficients"
# plot without title

# %%
#plotting hatvalues(how much independent variables are far from m2014) and finding the index of the maximum variable
plot(hatvalues(lm.fit14))
which.max( hatvalues(lm.fit14))
# Out:
# 99
# 99
# plot without title

# %%
#2015 (Same fitting as 2014)

fix(data15)
names(data15)
data15["m2015"]<- data15["Violent.crime"]*10000/ data15["Population"]
data15
lm.fit2=lm(m2015~ Murder.and.nonnegligent.manslaughter + Rape..revised.definition. + Robbery + Rape..legacy.definition. + Aggravated.assault, data=data15)
summary(lm.fit2)
# Out:
#  [1] "X"
#  [2] "State"
#  [3] "Area"
#  [4] "Population"
#  [5] "Violent.crime"
#  [6] "Murder.and.nonnegligent.manslaughter"
#  [7] "Rape..revised.definition."
#  [8] "Robbery"
#  [9] "Rape..legacy.definition."
# [10] "Aggravated.assault"
#     X   State                Area                              Population
# 1    0  ALABAMA              Metropolitan Statistical Area      3708033
# 2    1  ALABAMA              Cities outside metropolitan areas   522241
# 3    2  ALABAMA              Nonmetropolitan counties            628705
# 4    4  ALASKA               Metropolitan Statistical Area       351857
# 5    5  ALASKA               Cities outside metropolitan areas   127499
# 6    6  ALASKA               Nonmetropolitan counties            259076
# 7    8  ARIZONA              Metropolitan Statistical Area      6479810
# 8    9  ARIZONA              Cities outside metropolitan areas   124240
# 9   10  ARIZONA              Nonmetropolitan counties            224015
# 10  12  ARKANSAS             Metropolitan Statistical Area      1837196
# 11  13  ARKANSAS             Cities outside metropolitan areas   515124
# 12  14  ARKANSAS             Nonmetropolitan counties            625884
# 13  16  CALIFORNIA           Metropolitan Statistical Area     38317995
# 12    1559          15
# 13  163195        1815
# 14    1630          15
# 15    2034          31
# 16   16306         164
# 17     750           6
# 18     430           6
# 19    7441         102
# 20     110           1
# 21     294          14
# 22    4720          63
# 23    8531         162
# 24   89825         999
# 25    1032          12
# 26    2555          29
# 27   32186         508
# 28    2910          41
# 29    2334          48
# 30    2994          19
# ... ...           ...
# 116   1626          12
# 117   1391           7
# 118    158          10
# 119  34397         351
# 120   3364          16
# 121   2639          39
# 122 104453        1207
# 123   5528          43
# 124   2958          65
# 125   6295          49
# 126    337           1
# 127    346           4
# 128    279           2
# 129    307           5
# 130    153           3
# 131  14490         328
# 132    721          19
# 133   1182          36
# 134  18899         197
# 135    922           6
# 136    553           8
# 137   3557          45
# 138    280           4
# 139   1325          11
# 140  15597         207
# 141   1015           9
# 142    795          21
# 143    366           8
# 144    629           5
# 145    262           3
#     Rape..revised.definition. Robbery Rape..legacy.definition.
# 1    1496                      4080   1080
# 2     311                       354    218
# 3     186                       112    122
# 4     541                       658    401
# 5     178                        60    128
# 6     176                        41    116
# 7    2805                      6239   2072
# 8     269                        91    199
# 9      11                        12      7
# 10   1133                      1673    838
# 11    406                       333    248
# 12    292                        47    143
# 13  12411                     52439   9116
# 14    151                       245    106
# 15    247                       170    164
# 16   2991                      3235   2196
# 17    167                        75    119
# 18     95                        11     58
# 19    694                      2819    521
# 20     23                        27     20
# 21     56                        46     41
# 22    341                      1235    243
# 23    494                      3742    366
# 24   7321                     20811   5273
# 25     54                       160     37
# 26    162                       126    108
# 27   2568                     11058   1845
# 28    258                       691    191
# 29    294                       170    186
# 30    412                      1009    302
# ... ...                       ...     ...
# 116   303                       165    275
# 117   160                        40    138
# 118    18                         7     18
# 119  2260                      7078   1659
# 120   253                       295    183
# 121   163                       101    124
# 122 11040                     31163   8068
# 123   657                       602    472
# 124   512                       127    350
# 125  1448                      1292    969
# 126    95                        12     50
# 127    79                        10     61
# 128    50                        47     48
# 129    48                        42     44
# 130    38                        12     29
# 131  1920                      4194   1252
# 132   115                       139     72
# 133   305                       107    169
# 134  2438                      5234   1965
# 135   173                       165    151
# 136    91                        46     74
# 137   402                       625    245
# 138    23                        28     18
# 139   142                        29     83
# 140  1368                      5087    923
# 141   189                        79    141
# 142   183                        17    129
# 143    50                        31     36
# 144    82                        24     62
# 145    35                         3     23
#     Aggravated.assault m2015
# 1   12263               48.872273
# 2    2481               60.853131
# 3     879               19.166382
# 4    2238               98.449086
# 5     638               69.490741
# 6     776               39.177693
# 7   15401               38.156983
# 8    2294              215.550547
# 9     354               16.963150
# 10   7794               58.371562
# 11   1949               52.880471
# 12   1205               24.908769
# 13  96530               42.589650
# 14   1219               60.708313
# 15   1586               36.430329
# 16   9916               34.228373
# 17    502               22.382715
# 18    318               12.024272
# 19   3826               25.207980
# 20     59                9.608246
# 21    178                5.604719
# 22   3081               49.897773
# 23   4133              126.906347
# 24  60694               45.912521
# 25    806               69.790561
# 26   2238               45.704902
# 27  18052               38.126849
# 28   1920               45.238810
# 29   1822               20.658761
# 30   1554               25.716502
# ... ...                ...
# 116  1146              39.430800
# 117  1184              63.353115
# 118   123               6.974547
# 119 24708              67.399900
# 120  2800              65.467213
# 121  2336              26.845460
# 122 61043              42.769166
# 123  4226              38.772385
# 124  2254              18.249616
# 125  3506              23.526228
# 126   229              23.259506
# 127   253              19.738156
# 128   180              12.851813
# 129   212              15.084216
# 130   100               7.447865
# 131  8048              19.759933
# 132   448              27.516983
# 133   734              15.000914
# 134 11030              29.290213
# 135   578              31.109027
# 136   408              13.115205
# 137  2485              31.287878
# 138   225              14.797903
# 139  1143              25.576682
# 140  8935              36.538210
# 141   738              15.868971
# 142   574               9.211603
# 143   277              20.362973
# 144   518              25.616068
# 145   221              16.291506
# Call:
# lm(formula = m2015 ~ Murder.and.nonnegligent.manslaughter + Rape..revised.definition. +
#     Robbery + Rape..legacy.definition. + Aggravated.assault,
#     data = data15)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.747 -13.906  -5.929   6.382 180.995
#
# Coefficients:
#                                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)                          30.7041181  2.4503731  12.530   <2e-16 ***
# Murder.and.nonnegligent.manslaughter  0.0210905  0.0334139   0.631   0.5290
# Rape..revised.definition.            -0.0335228  0.0305475  -1.097   0.2744
# Robbery                              -0.0029937  0.0017608  -1.700   0.0913 .
# Rape..legacy.definition.              0.0393660  0.0416615   0.945   0.3463
# Aggravated.assault                    0.0020930  0.0009069   2.308   0.0225 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 24.65 on 139 degrees of freedom
# Multiple R-squared:  0.06169,	Adjusted R-squared:  0.02794
# F-statistic: 1.828 on 5 and 139 DF,  p-value: 0.1113

# %%
#we remove murder column as it has high p-value and we can see that aggravated assault has very low p-value so it fits the data very well

lm.fit15=lm(m2015~ Rape..revised.definition. + Robbery + Rape..legacy.definition. + Aggravated.assault, data=data15)
summary(lm.fit15)

predict(lm.fit15, data.frame(Aggravated.assault,interval ="confidence"))

plot(Aggravated.assault, m2014)
abline(lm.fit14)
plot(hatvalues(lm.fit15))
which.max( hatvalues(lm.fit15))
# Out:
# Call:
# lm(formula = m2015 ~ Rape..revised.definition. + Robbery + Rape..legacy.definition. +
#     Aggravated.assault, data = data15)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -31.320 -14.241  -5.705   7.299 180.811
#
# Coefficients:
#                             Estimate Std. Error t value Pr(>|t|)
# (Intercept)               31.0592107  2.3797887  13.051   <2e-16 ***
# Rape..revised.definition. -0.0293143  0.0297468  -0.985   0.3261
# Robbery                   -0.0024715  0.0015510  -1.594   0.1133
# Rape..legacy.definition.   0.0341981  0.0407611   0.839   0.4029
# Aggravated.assault         0.0021731  0.0008961   2.425   0.0166 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 24.59 on 140 degrees of freedom
# Multiple R-squared:  0.059,	Adjusted R-squared:  0.03211
# F-statistic: 2.194 on 4 and 140 DF,  p-value: 0.07267
#        1        2        3        4        5        6        7        8
# 36.72271 33.05820 31.60413 32.06867 31.56267 31.35675 36.43760 31.31381
#        9       10       11       12       13       14       15       16
# 31.81915 38.39881 30.48929 30.21946 57.30362 32.16160 32.16487 31.59901
#       17       18       19       20       21       22       23       24
# 29.61406 30.32038 29.93042 31.11460 30.69624 31.38230 29.58149 80.43988
#       25       26       27       28       29       30       31       32
# 31.92553 33.35596 29.09152 32.73245 32.71603 30.64741 30.99611 32.81455
#       33       34       35       36       37       38       39       40
# 31.93332 31.77561 33.81994 32.86212 31.32542 34.08596 31.82697 32.07094
#       41       42       43       44       45       46       47       48
# 34.62316 32.70638 31.87060 35.81769 33.25339 31.70456 24.51878 30.63007
#       49       50       51       52       53       54       55       56
# 27.33361 42.32522 32.96134 32.19512 30.78832 30.91809 30.74776 31.50166
#       57       58       59       60       61       62       63       64
# 31.42015 31.21512 47.01331 30.94709 31.00709 32.39843 28.53865 27.16093
#       65       66       67       68       69       70       71       72
# 27.88784 31.20154 30.59370 29.64184 31.03394 31.10614 40.31733 34.22239
#       73       74       75       76       77       78       79       80
# 33.56562 31.63523 32.67419 32.65861 31.35085 31.35634 31.02240 32.93756
#       81       82       83       84       85       86       87       88
# 31.47359 31.25935 31.15757 31.02836 31.05161 24.74995 34.71948 33.95729
#       89       90       91       92       93       94       95       96
# 31.74560 47.66557 31.26909 28.10842 40.49119 33.88236 32.61280 32.14793
#       97       98       99      100      101      102      103      104
# 31.45449 31.14710 24.74039 31.69758 30.83239 35.17402 33.68670 31.71041
#      105      106      107      108      109      110      111      112
# 31.41539 30.86124 31.19173 28.41720 32.74980 29.79324 23.46656 31.01040
#      113      114      115      116      117      118      119      120
# 31.23205 45.16102 32.73161 33.44430 33.31266 33.00568 31.24706 58.46336
#      121      122      123      124      125      126      127      128
# 35.68710 34.92609 36.73919 36.44815 32.93525 25.50892 30.62607 31.12084
#      129      130      131      132      133      134      135      136
# 31.39967 31.36775 31.33700 25.04728 30.53070 28.66388 35.93615 31.97964
#      137      138      139      140      141      142      143      144
# 31.78448 31.19415 31.67425 32.18319 30.21693 31.74659 30.83102 31.25954
#      145      146
# 31.79004 31.13228
# Warning message in abline(lm.fit14):
# "only using the first two of 5 regression coefficients"
# plot without title
# 13
# 13
# plot without title

# %%
#null hypothesis
attach(data14)
attach(data15)
mean_df_14 =  matrix(data = 0, nrow = 146, ncol = 1)
mean_df_15 = matrix(data = 0, nrow = 146, ncol = 1)

for  (i in 1:146) {
  s1 = sample(data14$m2014, 146, replace = TRUE)
  s2 = sample(data15$m2015, 30, replace = TRUE)
  
  mean_df_14[i] = mean(s1)
  mean_df_15[i] = mean(s2)
}
alpha = 0.01
alphahalf = alpha / 2
lower = alphahalf
upper = 1-alphahalf
r = 1
q = quantile(mean_df_14, c(lower, upper), na.rm = TRUE)
print(c(alpha,q[1],q[2]))
  
mean_crime_15 = mean(mean_df_15)
# Out:
# The following objects are masked from data14 (pos = 3):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 4):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data15 (pos = 5):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 6):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 7):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 8):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 9):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 10):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 11):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 12):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data15 (pos = 13):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 14):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 15):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 16):
#
#     Aggravated.assault, aggravated_assault_2016, Area, m2014,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 3):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 4):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 5):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data15 (pos = 6):
#
#     Aggravated.assault, Area, m2015,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 7):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 8):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 9):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 10):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 11):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 12):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 13):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data15 (pos = 14):
#
#     Aggravated.assault, Area, m2015,
#     Murder.and.nonnegligent.manslaughter, Population,
#     Rape..legacy.definition., Rape..revised.definition., Robbery,
#     State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 15):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 16):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#
# The following objects are masked from data14 (pos = 17):
#
#     Aggravated.assault, Area, Murder.and.nonnegligent.manslaughter,
#     Population, Rape..legacy.definition., Rape..revised.definition.,
#     Robbery, State, Violent.crime, X
#              0.5%    99.5%
#  0.01000 27.53058 35.49602

# %%
#test the null hypothesis that the crime per 10,000 population in 2014 is same as the crime per 10,000 popuplation in 2015

if (( mean_crime_15> q[1]) & (mean_crime_15 < q[2])) {print("ACCEPT")}
if ((mean_crime_15 <= q[1]) || (mean_crime_15 >= q[2])) {print("REJECT")}
print(c(alpha,q[1],q[2]))
print("Mean crime 2015")
mean_crime_15
# Out:
# [1] "ACCEPT"
#              0.5%    99.5%
#  0.01000 27.53058 35.49602
# [1] "Mean crime 2015"
# [1] 32.7847
